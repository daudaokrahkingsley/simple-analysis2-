# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('people.csv')
df
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# 2              fhoward@example.org          (599)782-0605    2013-11-25
# 3            zjohnston@example.com        +1-939-130-6258    2012-11-17
# 4                 elin@example.net     (390)417-1635x3010    1923-04-15
# ..                             ...                    ...           ...
# 995         lyonsdaisy@example.net           021.775.2933    1959-01-05
# 996        dariusbryan@example.com   001-149-710-7799x721    2001-10-06
# 997         georgechan@example.org  +1-750-774-4128x33265    1918-05-13
# 998            wanda04@example.net          (915)292-2254    1971-08-31
# 999        deannablack@example.org     079.752.5424x67259    1947-01-24
#
#                            Job Title
# 0                  Probation officer
# 1                             Dancer
# 2                               Copy
# 3           Counselling psychologist
# 4                Biomedical engineer
# ..                               ...
# 995                Personnel officer
# 996          Education administrator
# 997  Commercial/residential surveyor
# 998                 Ambulance person
# 999       Nurse, learning disability
#
# [1000 rows x 9 columns]

# %% [markdown]
# # Analysis Aspect

# %%
df.isna().sum()
# Out:
# Index            0
# User Id          0
# First Name       0
# Last Name        0
# Sex              0
# Email            0
# Phone            0
# Date of birth    0
# Job Title        0
# dtype: int64

# %% [markdown]
# #### _This Shows that there is no Null columns in the Dataset_

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1000 non-null   int64
#  1   User Id        1000 non-null   object
#  2   First Name     1000 non-null   object
#  3   Last Name      1000 non-null   object
#  4   Sex            1000 non-null   object
#  5   Email          1000 non-null   object
#  6   Phone          1000 non-null   object
#  7   Date of birth  1000 non-null   object
#  8   Job Title      1000 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 70.4+ KB

# %%
df.tail()
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                        Email                  Phone Date of birth  \
# 995   lyonsdaisy@example.net           021.775.2933    1959-01-05
# 996  dariusbryan@example.com   001-149-710-7799x721    2001-10-06
# 997   georgechan@example.org  +1-750-774-4128x33265    1918-05-13
# 998      wanda04@example.net          (915)292-2254    1971-08-31
# 999  deannablack@example.org     079.752.5424x67259    1947-01-24
#
#                            Job Title
# 995                Personnel officer
# 996          Education administrator
# 997  Commercial/residential surveyor
# 998                 Ambulance person
# 999       Nurse, learning disability

# %%
df.shape
# Out:
# (1000, 9)

# %%
df['Sex'].value_counts()
# Out:
# Male      506
# Female    494
# Name: Sex, dtype: int64

# %%
df.describe(include=['object'])
# Out:
#                 User Id First Name Last Name   Sex                Email  \
# count              1000       1000      1000  1000                 1000
# unique             1000        526       628     2                 1000
# top     02C553bfcFA32bA         Jo      Duke  Male  shane47@example.org
# freq                  1          6         6   506                    1
#
#                Phone Date of birth       Job Title
# count           1000          1000            1000
# unique          1000           991             519
# top     212-112-3077    1983-10-08  Phytotherapist
# freq               1             2               7

# %%
df['Sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Job Title'].unique()
# Out:
# array(['Probation officer', 'Dancer', 'Copy', 'Counselling psychologist',
#        'Biomedical engineer', 'Higher education lecturer',
#        'Health visitor', 'Air broker', 'Designer, multimedia',
#        'Insurance account manager', 'Scientist, water quality',
#        'Metallurgist', 'Dramatherapist', 'Presenter, broadcasting',
#        'Nurse, mental health', 'Therapeutic radiographer', 'Land',
#        'Recruitment consultant', 'Accounting technician',
#        'Education officer, museum', 'Tax inspector', 'Engineer, land',
#        'Printmaker', 'Personnel officer', 'Race relations officer',
#        'Microbiologist', 'Industrial buyer',
#        'Production assistant, radio', 'Agricultural consultant',
#        'Chief Financial Officer', 'Insurance broker',
#        'Information systems manager', 'Psychologist, sport and exercise',
#        'Ergonomist', 'Sports therapist', 'Comptroller',
#        'Claims inspector/assessor', 'Hospital doctor',
#        'Investment banker, corporate', 'Pilot, airline',
#        'Insurance underwriter', 'Engineer, mining',
#        'Armed forces technical officer', 'Psychologist, educational',
#        'Housing manager/officer', 'Dentist', 'Prison officer',
#        'Restaurant manager', 'Psychotherapist, dance movement',
#        'Human resources officer', 'Nurse, adult', 'Seismic interpreter',
#        'Barrister', 'Engineer, structural', 'Producer, radio',
#        'Therapist, nutritional', 'Paediatric nurse',
#        'Production engineer', 'Accountant, chartered certified',
#        'Administrator', 'Data scientist', 'Occupational hygienist',
#        'Art therapist', 'Academic librarian', 'Musician',
#        'Engineer, petroleum', 'Journalist, newspaper', 'Surgeon',
#        'Building surveyor', 'Veterinary surgeon', 'Orthoptist',
#        'Administrator, arts', 'Museum/gallery curator', 'Neurosurgeon',
#        'Designer, fashion/clothing', 'Local government officer',
#        'Research officer, trade union', 'Health and safety adviser',
#        'Civil engineer, contracting', 'Publishing rights manager',
#        'Surveyor, commercial/residential', 'Actuary',
#        'Medical sales representative', 'Art gallery manager',
#        'Engineer, materials', 'Immigration officer',
#        'Environmental health practitioner', 'Accountant, chartered',
#        'Legal executive', 'Translator', 'Fitness centre manager',
#        'Games developer', 'Surveyor, building control',
#        'Field seismologist', 'Dance movement psychotherapist',
#        'Engineer, technical sales', 'Audiological scientist',
#        'Commercial art gallery manager', 'Retail buyer',
#        'Psychologist, clinical', 'Waste management officer',
#        'Garment/textile technologist', 'Geophysical data processor',
#        'Nutritional therapist', 'Clinical biochemist',
#        'Runner, broadcasting/film/video',
#        'Armed forces logistics/support/administrative officer',
#        'Surveyor, hydrographic', 'Museum/gallery conservator',
#        'Television camera operator', 'Hydrographic surveyor',
#        'IT sales professional', 'Clinical research associate', 'Artist',
#        'Engineer, agricultural', 'Museum/gallery exhibitions officer',
#        'Interior and spatial designer', 'Financial adviser',
#        'Glass blower/designer', 'Herbalist', 'Stage manager',
#        'Engineer, manufacturing', 'Development worker, community',
#        'Loss adjuster, chartered', 'Research scientist (life sciences)',
#        'Fashion designer', 'Product/process development scientist',
#        'Chiropodist', 'Civil engineer, consulting',
#        'Chief Executive Officer', 'Health promotion specialist',
#        'Surveyor, building', 'Writer', 'Archaeologist', 'Teacher, music',
#        'Biochemist, clinical', 'Tree surgeon',
#        'Architectural technologist', 'Product designer',
#        'Commercial/residential surveyor', 'General practice doctor',
#        'Social worker', 'Camera operator', 'Food technologist',
#        'Careers information officer', 'Designer, textile',
#        'Graphic designer', 'Private music teacher',
#        'Primary school teacher', 'Engineer, control and instrumentation',
#        'Dietitian', 'Purchasing manager', 'Therapist, music',
#        'Engineer, electrical', 'Quantity surveyor',
#        'Secretary/administrator', 'Social research officer, government',
#        'Early years teacher', 'Engineer, aeronautical',
#        'Teacher, special educational needs', 'Visual merchandiser',
#        'Advertising art director',
#        'Historic buildings inspector/conservation officer',
#        'Engineer, broadcasting (operations)', 'Risk analyst',
#        'Retail manager', 'Librarian, academic',
#        'Fast food restaurant manager', 'Public house manager',
#        'Accommodation manager', 'Medical secretary',
#        'Engineer, automotive', 'Landscape architect',
#        'Manufacturing systems engineer', 'Merchandiser, retail',
#        'Professor Emeritus', 'Adult nurse', 'Engineer, communications',
#        'Chief Marketing Officer', 'Amenity horticulturist',
#        'Production manager', 'Multimedia programmer', 'Illustrator',
#        'Research scientist (medical)', 'Insurance claims handler',
#        'Set designer', 'Health physicist',
#        'Emergency planning/management officer',
#        'Logistics and distribution manager', 'Lobbyist',
#        'Horticultural therapist', 'Speech and language therapist',
#        'Pharmacist, hospital', 'Dispensing optician',
#        'Editor, commissioning', 'Geophysicist/field seismologist',
#        'Tour manager', 'Oceanographer', 'Geneticist, molecular',
#        'Clothing/textile technologist',
#        'Tourist information centre manager',
#        'Research officer, political party',
#        'Television/film/video producer', "Politician's assistant",
#        'Chemical engineer', 'Music therapist', 'Ranger/warden',
#        'Civil Service administrator', 'Materials engineer',
#        'Restaurant manager, fast food', 'Banker', 'Optometrist',
#        'Clinical cytogeneticist', 'Scientist, forensic',
#        'Medical laboratory scientific officer',
#        'Public relations account executive', 'Technical author',
#        'Water quality scientist', 'Computer games developer',
#        'Adult guidance worker', 'Scientist, audiological',
#        'Civil Service fast streamer', 'Licensed conveyancer',
#        'Engineer, drilling', 'Programmer, multimedia', 'Photographer',
#        'Diplomatic Services operational officer',
#        'Senior tax professional/tax inspector', 'Fisheries officer',
#        'Conservator, furniture', 'Contractor', 'Ship broker',
#        'Land/geomatics surveyor', 'Product manager',
#        'Scientist, physiological', 'Information officer', 'Buyer, retail',
#        'Facilities manager', 'Psychotherapist', 'Paramedic',
#        'Control and instrumentation engineer', 'Doctor, general practice',
#        'Corporate investment banker', 'Analytical chemist',
#        'Arts administrator', 'Travel agency manager',
#        'Newspaper journalist', 'Conservation officer, nature',
#        'Programme researcher, broadcasting/film/video', 'Media buyer',
#        'Tax adviser', 'Biomedical scientist', 'Engineer, electronics',
#        'Radiation protection practitioner', 'Catering manager',
#        'Education officer, environmental', 'Operations geologist',
#        'Brewing technologist', 'Mental health nurse', 'Architect',
#        'Broadcast presenter', 'Leisure centre manager', 'Podiatrist',
#        "Nurse, children's", 'Solicitor, Scotland', 'Learning mentor',
#        'Plant breeder/geneticist', 'Media planner', 'Cartographer',
#        'Forensic psychologist', 'Immunologist', 'Sales executive',
#        'Scientist, research (physical sciences)',
#        'Education administrator', 'Scientist, research (medical)',
#        'Furniture designer', 'Clinical embryologist', 'Medical physicist',
#        'Investment analyst', 'Doctor, hospital',
#        'Editor, magazine features', 'Lecturer, higher education',
#        'Animal technologist', 'Best boy', 'Records manager',
#        'Engineer, manufacturing systems', 'Scientist, biomedical',
#        'Chiropractor', 'Radio producer', 'Chief Strategy Officer',
#        'Associate Professor', 'Market researcher', 'Geochemist',
#        'Patent examiner', 'Network engineer',
#        'Telecommunications researcher', 'Applications developer',
#        'Trade union research officer', 'Dealer', 'Warden/ranger',
#        'Database administrator', 'Radiographer, therapeutic',
#        'Surveyor, quantity', 'Nature conservation officer',
#        'Wellsite geologist', "Barrister's clerk",
#        'Financial risk analyst', 'Medical technical officer',
#        'Clinical psychologist', 'Energy engineer',
#        'Trading standards officer',
#        'International aid/development worker',
#        'Production assistant, television', 'Theatre director',
#        'Arts development officer', 'Hotel manager', 'Barista',
#        'Surveyor, planning and development',
#        'Sport and exercise psychologist', 'Designer, furniture',
#        'Building control surveyor', 'Librarian, public',
#        'Research scientist (maths)', 'Gaffer', 'Solicitor',
#        'Animal nutritionist', 'Jewellery designer',
#        'Data processing manager', 'Horticulturist, amenity',
#        'Museum education officer', 'Minerals surveyor',
#        'Technical brewer', 'Phytotherapist',
#        'Accountant, chartered public finance', 'Astronomer',
#        'Chartered certified accountant', 'Occupational psychologist',
#        'Field trials officer', 'Teacher, primary school',
#        'Maintenance engineer', 'Haematologist',
#        'Administrator, Civil Service', 'Engineer, civil (contracting)',
#        'Osteopath', 'IT technical support officer', 'Fish farm manager',
#        'Publishing copy', 'Counsellor', 'Legal secretary',
#        'Investment banker, operational', 'Volunteer coordinator',
#        'Psychiatric nurse', 'Psychologist, counselling',
#        'Scientist, research (life sciences)', 'Bookseller',
#        'Personal assistant', 'Electronics engineer',
#        'Designer, jewellery', 'Naval architect', 'Theme park manager',
#        'Health and safety inspector', 'Medical illustrator',
#        'Geologist, engineering',
#        'Scientist, clinical (histocompatibility and immunogenetics)',
#        'Scientific laboratory technician', 'Quality manager',
#        'Holiday representative', 'Journalist, magazine', 'Estate agent',
#        'Mechanical engineer', 'Armed forces operational officer',
#        'Public affairs consultant', 'Firefighter',
#        'Training and development officer', 'Recycling officer',
#        'Administrator, sports', 'Agricultural engineer',
#        'Secondary school teacher', 'Physiological scientist',
#        'Web designer', 'Therapist, sports', 'Archivist',
#        'Trade mark attorney', 'Ceramics designer', 'Video editor',
#        'Sound technician, broadcasting/film/video',
#        'Horticulturist, commercial', 'Tourism officer',
#        'Conservator, museum/gallery',
#        'Clinical scientist, histocompatibility and immunogenetics',
#        'TEFL teacher', 'Film/video editor', 'Psychotherapist, child',
#        'Armed forces training and education officer',
#        'Production designer, theatre/television/film',
#        'Diagnostic radiographer', 'Engineer, maintenance (IT)',
#        'Event organiser', 'Clinical molecular geneticist',
#        'Customer service manager', 'Charity fundraiser',
#        'Systems analyst', 'Theatre manager', 'Physiotherapist',
#        'Communications engineer', 'Cabin crew', 'Interpreter',
#        'Advertising account executive', 'Journalist, broadcasting',
#        'Engineer, production', 'Engineer, civil (consulting)',
#        'Planning and development surveyor', 'Financial planner',
#        'Management consultant', 'Company secretary',
#        'Exhibitions officer, museum/gallery',
#        'Designer, industrial/product', 'Contracting civil engineer',
#        'Operational researcher', 'Environmental consultant',
#        'Sports development officer', 'Fine artist', 'Secretary, company',
#        'Teacher, adult education', 'Financial controller',
#        'Conservation officer, historic buildings',
#        'Television production assistant', 'Magazine journalist',
#        'Heritage manager', 'Youth worker', 'Building services engineer',
#        'Administrator, education', 'Automotive engineer',
#        'Engineering geologist', 'Bonds trader',
#        'Teacher, English as a foreign language',
#        'Public relations officer', 'Therapist, drama', 'Press sub', 'Sub',
#        'Chemist, analytical', 'Industrial/product designer',
#        'Warehouse manager', 'Education officer, community',
#        'Teaching laboratory technician', 'Forensic scientist',
#        'Mudlogger', 'Actor', 'Intelligence analyst',
#        'English as a second language teacher', 'Sports administrator',
#        'Homeopath', 'Advertising account planner', 'Town planner',
#        'Ecologist', 'Curator', 'Development worker, international aid',
#        'Surveyor, minerals', 'Social researcher', 'Make',
#        'Ambulance person', 'Freight forwarder', 'Psychiatrist',
#        'Editor, film/video', 'Farm manager', 'Energy manager',
#        'Editorial assistant', 'Herpetologist', 'Surveyor, mining',
#        'Chartered management accountant', 'Rural practice surveyor',
#        'Engineer, biomedical', 'Designer, blown glass/stained glass',
#        'Water engineer', 'Theatre stage manager',
#        'Chief Technology Officer', 'Engineer, water', 'Retail banker',
#        'Acupuncturist', 'Proofreader', 'Cytogeneticist',
#        'Drilling engineer', 'Forest/woodland manager', 'Animator',
#        'Soil scientist', 'Environmental education officer',
#        'Buyer, industrial', 'Chief Operating Officer',
#        'Engineer, chemical', 'Technical sales engineer', 'Toxicologist',
#        'Commissioning editor', 'Conference centre manager',
#        'Multimedia specialist', 'Teacher, secondary school',
#        'Marine scientist', 'Pensions consultant',
#        'Programmer, applications', 'Advice worker',
#        'Engineer, maintenance', 'Call centre manager',
#        'Copywriter, advertising', 'Designer, ceramics/pottery',
#        'Geographical information systems officer', 'Office manager',
#        'Optician, dispensing', 'Pharmacologist',
#        'Outdoor activities/education manager', 'Environmental manager',
#        'Location manager', 'Embryologist, clinical', 'Systems developer',
#        'Consulting civil engineer', 'Scientist, research (maths)',
#        'Airline pilot', 'Psychologist, prison and probation services',
#        'Horticultural consultant', 'Petroleum engineer',
#        'Nurse, learning disability'], dtype=object)

# %% [markdown]
# ## Visualisation Aspect

# %%
df['Sex'].value_counts().plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
df.corr(method='spearman')
# Out:
#        Index
# Index    1.0
